# %% [markdown]
# # Setup Street Fighter II

# %%
print("debut du code")
# Out:
# debut du code

# %%
! pip install gym gym-retro
# Out:
# ...
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/721.7 kB ? eta -:--:--
#      - ----------------------------------- 30.7/721.7 kB 262.6 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/721.7 kB 245.8 kB/s eta 0:00:03
#      ---- -------------------------------- 92.2/721.7 kB 476.3 kB/s eta 0:00:02
#      ----------------- -------------------- 327.7/721.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------  716.8/721.7 kB 2.7 MB/s eta 0:00:01
#      -------------------------------------- 721.7/721.7 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
import retro
